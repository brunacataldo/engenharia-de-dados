# %% [markdown]
# <a href="https://colab.research.google.com/github/brunacataldo/engenharia-de-dados/blob/master/testes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/10. Movimentação de passageiros em rodoviárias do Basil__A2022-2021-V49-1ed.xlsx', sheet_name = 1, header=[4], skipfooter= 86)

# %%
# df.drop(df.columns[[0,2,3,4,5,6,8,12,14,16,18,20]],axis=1, inplace= True)

# %%
df
# Out:
#     Unnamed: 0     Ano  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0          NaN     NaN         NaN         NaN         NaN
# 1          NaN     NaN         NaN         NaN         NaN
# 2          NaN     NaN         NaN         NaN         NaN
# 3          NaN  2010.0         NaN         NaN         NaN
# 4          NaN     NaN         NaN         NaN         NaN
# 5          NaN  2011.0         NaN         NaN         NaN
# 6          NaN     NaN         NaN         NaN         NaN
# 7          NaN  2012.0         NaN         NaN         NaN
# 8          NaN     NaN         NaN         NaN         NaN
# 9          NaN  2013.0         NaN         NaN         NaN
# 10         NaN     NaN         NaN         NaN         NaN
# 11         NaN  2014.0         NaN         NaN         NaN
# 12         NaN     NaN         NaN         NaN         NaN
# 13         NaN  2015.0         NaN         NaN         NaN
# 14         NaN     NaN         NaN         NaN         NaN
# ...

# %%
df.shape
# Out:
# (32, 10)

# %%
df2 = df.dropna(inplace= True)
